# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Comparison.csv').drop(['start_time', 'end_time'], axis=1)

# %%
df.head()
# Out:
#    double_LSTM  sequence_size  epoches  batch_size  trainScoreMAE  \
# 0        False              5        5          16     996.859659
# 1        False              5        5          16    1958.891519
# 2        False              5        5          16      29.490195
# 3        False              5        5          16     114.360635
# 4        False              5        5          16    1020.362344
#
#    trainScoreMSE  trainScoreRMSE  testScoreMAE  testScoreMSE  testScoreRMSE
# 0   9.937292e+05      996.859659     47.949229   2299.128568      47.949229
# 1   3.837256e+06     1958.891519     75.679210   5727.342755      75.679210
# 2   8.696716e+02       29.490195     75.171865   5650.809241      75.171865
# 3   1.307835e+04      114.360635    180.296397  32506.790780     180.296397
# 4   1.041139e+06     1020.362344    225.823741  50996.361900     225.823741

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   double_LSTM     900 non-null    bool
#  1   sequence_size   900 non-null    int64
#  2   epoches         900 non-null    int64
#  3   batch_size      900 non-null    int64
#  4   trainScoreMAE   900 non-null    float64
#  5   trainScoreMSE   900 non-null    float64
#  6   trainScoreRMSE  900 non-null    float64
#  7   testScoreMAE    900 non-null    float64
#  8   testScoreMSE    900 non-null    float64
#  9   testScoreRMSE   900 non-null    float64
# dtypes: bool(1), float64(6), int64(3)
# memory usage: 64.3 KB

# %%
df.describe()
# Out:
#        sequence_size     epoches  batch_size  trainScoreMAE  trainScoreMSE  \
# count     900.000000  900.000000  900.000000     900.000000   9.000000e+02
# mean       15.000000    7.500000   37.333333     573.577231   6.587730e+05
# std         7.074999    1.708775   19.966602     574.585890   1.456525e+06
# min         5.000000    5.000000   16.000000       0.224814   5.054143e-02
# 25%        10.000000    6.000000   16.000000     184.884625   3.418232e+04
# 50%        15.000000    7.500000   32.000000     402.699888   1.621673e+05
# 75%        20.000000    9.000000   64.000000     741.188966   5.493612e+05
# max        25.000000   10.000000   64.000000    3708.611441   1.375380e+07
#
#        trainScoreRMSE  testScoreMAE   testScoreMSE  testScoreRMSE
# count      900.000000    900.000000     900.000000     900.000000
# mean       573.577231    129.402279   28836.198170     129.402279
# std        574.585890    110.021353   53923.894802     110.021353
# ...

# %%
sequence_trainScore_cmp = df.drop(['double_LSTM', 'testScoreMAE', 'testScoreMSE', 'testScoreRMSE'], axis=1)
sequence_trainScore_cmp.info()
sns.pairplot(sequence_trainScore_cmp, hue='sequence_size',palette='Dark2')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sequence_size   900 non-null    int64
#  1   epoches         900 non-null    int64
#  2   batch_size      900 non-null    int64
#  3   trainScoreMAE   900 non-null    float64
#  4   trainScoreMSE   900 non-null    float64
#  5   trainScoreRMSE  900 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 42.3 KB

# %%
sequence_testScore_cmp = df.drop(['double_LSTM', 'trainScoreMAE', 'trainScoreMSE', 'trainScoreRMSE'], axis=1)
sequence_testScore_cmp.info()
sns.pairplot(sequence_testScore_cmp, hue='sequence_size',palette='Dark2')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sequence_size  900 non-null    int64
#  1   epoches        900 non-null    int64
#  2   batch_size     900 non-null    int64
#  3   testScoreMAE   900 non-null    float64
#  4   testScoreMSE   900 non-null    float64
#  5   testScoreRMSE  900 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 42.3 KB

# %%
epoches_trainScore_cmp = df.drop(['double_LSTM', 'testScoreMAE', 'testScoreMSE', 'testScoreRMSE'], axis=1)
epoches_trainScore_cmp.info()
sns.pairplot(epoches_trainScore_cmp, hue='epoches',palette='Dark2')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sequence_size   900 non-null    int64
#  1   epoches         900 non-null    int64
#  2   batch_size      900 non-null    int64
#  3   trainScoreMAE   900 non-null    float64
#  4   trainScoreMSE   900 non-null    float64
#  5   trainScoreRMSE  900 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 42.3 KB

# %%
epoches_testScore_cmp = df.drop(['double_LSTM', 'trainScoreMAE', 'trainScoreMSE', 'trainScoreRMSE'], axis=1)
epoches_testScore_cmp.info()
sns.pairplot(epoches_testScore_cmp, hue='epoches',palette='Dark2')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sequence_size  900 non-null    int64
#  1   epoches        900 non-null    int64
#  2   batch_size     900 non-null    int64
#  3   testScoreMAE   900 non-null    float64
#  4   testScoreMSE   900 non-null    float64
#  5   testScoreRMSE  900 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 42.3 KB

# %%
batchSize_trainScore_cmp = df.drop(['double_LSTM', 'testScoreMAE', 'testScoreMSE', 'testScoreRMSE'], axis=1)
batchSize_trainScore_cmp.info()
sns.pairplot(batchSize_trainScore_cmp, hue='batch_size',palette='Dark2')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sequence_size   900 non-null    int64
#  1   epoches         900 non-null    int64
#  2   batch_size      900 non-null    int64
#  3   trainScoreMAE   900 non-null    float64
#  4   trainScoreMSE   900 non-null    float64
#  5   trainScoreRMSE  900 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 42.3 KB

# %%
batchSize_testScore_cmp = df.drop(['double_LSTM', 'trainScoreMAE', 'trainScoreMSE', 'trainScoreRMSE'], axis=1)
batchSize_testScore_cmp.info()
sns.pairplot(batchSize_testScore_cmp, hue='batch_size',palette='Dark2')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sequence_size  900 non-null    int64
#  1   epoches        900 non-null    int64
#  2   batch_size     900 non-null    int64
#  3   testScoreMAE   900 non-null    float64
#  4   testScoreMSE   900 non-null    float64
#  5   testScoreRMSE  900 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 42.3 KB

# %%
df_grouped = df.groupby(['double_LSTM', 'sequence_size', 'epoches', 'batch_size']).mean()

# %%
df_grouped.head(900)
# Out:
#                                               trainScoreMAE  trainScoreMSE  \
# double_LSTM sequence_size epoches batch_size
# False       5             5       16             823.992870   1.177215e+06
#                                   32            1098.151333   1.344339e+06
#                                   64            1184.204458   1.447990e+06
#                           6       16             783.171264   9.500399e+05
#                                   32            1019.431240   1.214366e+06
# ...                                                     ...            ...
# True        25            9       32             293.510038   9.811185e+04
#                                   64             190.167398   5.931617e+04
#                           10      16             383.459062   1.816245e+05
#                                   32             294.683219   1.290732e+05
#                                   64             251.197898   7.918656e+04
#
# ...

# %%
df_grouped.sort_values(by=['trainScoreMAE']).head(5)
# Out:
#                                               trainScoreMAE  trainScoreMSE  \
# double_LSTM sequence_size epoches batch_size
# False       15            10      32              61.729065    8787.494333
#                           7       16              86.113976   10749.344882
#                           6       16              97.883435   13483.055622
# True        15            8       16              99.899378   17033.431560
#             20            9       16             107.582596   16788.402558
#
#                                               trainScoreRMSE  testScoreMAE  \
# double_LSTM sequence_size epoches batch_size
# False       15            10      32               61.729065    101.356664
#                           7       16               86.113976     86.204175
#                           6       16               97.883435     44.963110
# True        15            8       16               99.899378     74.531372
# ...

# %%
df_grouped.sort_values(by=['trainScoreMSE']).head(5)
# Out:
#                                               trainScoreMAE  trainScoreMSE  \
# double_LSTM sequence_size epoches batch_size
# False       15            10      32              61.729065    8787.494333
#                           7       16              86.113976   10749.344882
#                           6       16              97.883435   13483.055622
# True        5             9       32             108.548771   13606.004616
#             20            9       16             107.582596   16788.402558
#
#                                               trainScoreRMSE  testScoreMAE  \
# double_LSTM sequence_size epoches batch_size
# False       15            10      32               61.729065    101.356664
#                           7       16               86.113976     86.204175
#                           6       16               97.883435     44.963110
# True        5             9       32              108.548771     82.003127
# ...

# %%
df_grouped.sort_values(by=['trainScoreRMSE']).head(5)
# Out:
#                                               trainScoreMAE  trainScoreMSE  \
# double_LSTM sequence_size epoches batch_size
# False       15            10      32              61.729065    8787.494333
#                           7       16              86.113976   10749.344882
#                           6       16              97.883435   13483.055622
# True        15            8       16              99.899378   17033.431560
#             20            9       16             107.582596   16788.402558
#
#                                               trainScoreRMSE  testScoreMAE  \
# double_LSTM sequence_size epoches batch_size
# False       15            10      32               61.729065    101.356664
#                           7       16               86.113976     86.204175
#                           6       16               97.883435     44.963110
# True        15            8       16               99.899378     74.531372
# ...
